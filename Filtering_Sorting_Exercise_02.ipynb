# %% [markdown]
# <a href="https://colab.research.google.com/github/guannan11/DFE5/blob/main/Filtering_Sorting_Exercise_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. import libraries
import pandas as pd

# %%
# 3. Assign it to euro12 (variable)
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')
euro12
# Out:
#                    Team  Goals  ...  Subs off  Players Used
# 0               Croatia      4  ...         9            16
# 1        Czech Republic      4  ...        11            19
# 2               Denmark      4  ...         7            15
# 3               England      5  ...        11            16
# 4                France      3  ...        11            19
# 5               Germany     10  ...        15            17
# 6                Greece      5  ...        12            20
# 7                 Italy      6  ...        18            19
# 8           Netherlands      2  ...         7            15
# 9                Poland      2  ...         7            17
# 10             Portugal      6  ...        14            16
# 11  Republic of Ireland      1  ...        10            17
# 12               Russia      5  ...         7            16
# 13                Spain     12  ...        17            18
# 14               Sweden      5  ...         9            18
# ...

# %%
# 4. select goal column
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
# 5. how many teams in euro12?
euro12.shape[0]
# Out:
# 16

# %%
# 6. how many columns in this dataset?
euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
# 7. assgin 'team', 'yellow cards', 'red cards' columns into a new dataframe named discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# 8. sort teams by red cards, the yellow cards
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# 9. the mean yellow cards per team
round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %%
# 10.teams scored > 6 goals
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5   Germany     10               32  ...       15       15           17
# 13    Spain     12               42  ...       17       17           18
#
# [2 rows x 35 columns]

# %%
# 11. select the teams start with G
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5  Germany     10               32  ...       15       15           17
# 6   Greece      5                8  ...       12       12           20
#
# [2 rows x 35 columns]

# %%
# 12. select first 7 columns
euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  ...  % Goals-to-shots  Total shots (inc. Blocked)
# 0               Croatia      4  ...             16.0%                          32
# 1        Czech Republic      4  ...             12.9%                          39
# 2               Denmark      4  ...             20.0%                          27
# 3               England      5  ...             17.2%                          40
# 4                France      3  ...              6.5%                          65
# 5               Germany     10  ...             15.6%                          80
# 6                Greece      5  ...             19.2%                          32
# 7                 Italy      6  ...              7.5%                         110
# 8           Netherlands      2  ...              4.1%                          60
# 9                Poland      2  ...              5.2%                          48
# ...

# %%
# 13. all columns except last 3
euro12.iloc[:, : -3]
# Out:
#                    Team  Goals  ...  Yellow Cards  Red Cards
# 0               Croatia      4  ...             9          0
# 1        Czech Republic      4  ...             7          0
# 2               Denmark      4  ...             4          0
# 3               England      5  ...             5          0
# 4                France      3  ...             6          0
# 5               Germany     10  ...             4          0
# 6                Greece      5  ...             9          1
# 7                 Italy      6  ...            16          0
# 8           Netherlands      2  ...             5          0
# 9                Poland      2  ...             7          1
# 10             Portugal      6  ...            12          0
# 11  Republic of Ireland      1  ...             6          1
# 12               Russia      5  ...             6          0
# 13                Spain     12  ...            11          0
# ...

# %%
# 14. Shooting Accuracy from England, Italy and Russia
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
