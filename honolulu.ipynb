# %%
# %fs ls /databricks-datasets/structured-streaming/events/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.mount(source="wasbs://blahdrive@thisisrandomstorage.blob.core.windows.net",
                mount_point="/mnt/lake",
                extra_configs={"fs.azure.account.key.thisisrandomstorage.blob.core.windows.net": "oHTUfbbvJuoxUiLzChQNVSzrzrUAzEB1NGqpBBerssjXrulfFiX5htVkKFhppW7pB49EZd5n6saZmuy4ocd2Rw=="
                    
                })
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
# Hadoop -> sharded information storer-> OS (a lot of functionality on top of linux distributed file system) not just a tool
# some amount processing also-> algorithms
# MapReduce ---> Spark 
df = spark.read.csv('/mnt/lake/loan_data.csv', header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Data Store-> physical location-> SQL Server, MongoDB, MySQL Server, Synapse
# Data Sets-> schema and properties of data! 
# Data Frame-> a snapshot of data with the Data Set's schema (NOT FULL DATA)
# Table-> full data. Follows Data Set's schema and can extract multiple DataFrames depending on slicing and dicing!


df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------+----------+-------+------+-----+-------+
#  ID| Income|      Term|Balance|  Debt|Score|Default|
# +---+-------+----------+-------+------+-----+-------+
# 567|17500.0|Short Term| 1460.0| 272.0|225.0|  False|
# 523|18500.0| Long Term|  890.0| 970.0|187.0|  False|
# 544|20700.0|Short Term|  880.0| 884.0| 85.0|  False|
# 370|21600.0|Short Term|  920.0|   0.0| null|  False|
# 756|24300.0|Short Term| 1260.0|   0.0|495.0|  False|
# 929|22900.0| Long Term| 1540.0|1229.0|383.0|  False|
# 373|20400.0|Short Term| 1200.0|   0.0|556.0|  False|
# 818|24600.0|Short Term| 1470.0|   0.0|301.0|  False|
# ...

# %%
result = df.select(['Term','Balance'])
result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-------+
#       Term|Balance|
# +----------+-------+
# Short Term| 1460.0|
#  Long Term|  890.0|
# Short Term|  880.0|
# Short Term|  920.0|
# Short Term| 1260.0|
#  Long Term| 1540.0|
# Short Term| 1200.0|
# Short Term| 1470.0|
#  Long Term|  720.0|
# Short Term| 1130.0|
# Short Term|  910.0|
# Short Term|  820.0|
#  Long Term| 1300.0|
# Short Term| 1060.0|
# Short Term|  970.0|
# Short Term|  610.0|
# Short Term| 1020.0|
# Short Term|  940.0|
# Short Term| 1140.0|
# Short Term|  810.0|
# +----------+-------+
# only showing top 20 rows
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
